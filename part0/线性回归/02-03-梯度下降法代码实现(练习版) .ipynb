# %% [markdown]
# ## 梯度下降法举例

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ##### 求 $y=x^2+2x+5$的最小值

# %% [markdown]
# ###### 画函数图像

# %%
x = np.linspace(-6,4,100)
y = x**2+2*x+5
plt.plot(x,y)
# plt.show()

# %% [markdown]
# ##### 初始化 $x$ , $\alpha$ 和迭代次数

# %%
x = 3
alpha = 0.8
iterationNum = 100

# %% [markdown]
# ##### y的导数为2x+2,迭代求 theta

# %%
for i in range(iterationNum):
    ### 开始，约1行代码
    None
    ### 结束

# %% [markdown]
# ##### 输出最后的值

# %%
print(x)
# Out:
# -1.0
